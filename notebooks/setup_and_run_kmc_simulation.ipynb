# %% [markdown]
# # KMC simulation of PLD

# %%
import sys
import os
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('..') #/Users/l2v/work/kmcsim

# %% [markdown]
# Import kmc simulation tools

# %%
from kmcsim.buildtools import make_fcc, write_latt
from kmcsim.sim import KMCModel
from kmcsim.sim import EventTree
from kmcsim.sim import RunSim

# %% [markdown]
# Working directory (inputs, outputs)

# %%
wdir = '../data/working'

# %%
cat ../data/working/params
# Out:
# deposition: 0.1
# diffusion: 0.1

# %% [markdown]
# Set up simulation box and initial configuration of the substrate (with atoms filling the whole box)

# %%
# make substrate: perfect FCC lattice of given dimensions
box = [16, 32, 4]
latt = make_fcc(box)

# %%
# extend the box in the z-direction to make space for new layers to grow
latt['box'][3] = 256

# %%
# write initial configuration to xyz file in the working directory
write_latt(latt, os.path.join(wdir,'ni.xyz'))

# %%
sim = RunSim()

# %%
sim.read(os.path.join(wdir,'kmc.input'))

# %%
sim.init_sim()
# Out:
# Number of events: [512   0]
# tree level 0 (2,)
# tree level 1 (1,)

# %%
sim.run()
# Out:
# time, iteration, number of atoms
# 0.0 0 2048
# ee 0 394
# # event types: 0 [512, 0]
# atom numbers: 2048 1
# last atom coords: [30 31  3]
# # end events: 0 1 8
# ee 0 486
# # event types: 0 [515, 4]
# atom numbers: 2049 2
# last atom coords: [24 20  4]
# # end events: 0 1 8
# ee 0 243
# # event types: 0 [518, 8]
# atom numbers: 2050 3
# last atom coords: [30 14  4]
# # end events: 0 1 8
# ee 0 439
# # event types: 0 [521, 12]
# atom numbers: 2051 4
# last atom coords: [15  7  4]
# # end events: 0 1 8
# ee 0 405
# # event types: 0 [524, 16]
# atom numbers: 2052 5
# last atom coords: [27 19  4]
# # end events: 0 1 8
# ee 0 261
# # event types: 0 [527, 20]
# atom numbers: 2053 6
# last atom coords: [25 15  4]
# # end events: 0 1 8
# ee 0 178
# # event types: 0 [530, 24]
# atom numbers: 2054 7
# last atom coords: [16 12  4]
# # end events: 0 1 8
# ee 0 249
# # event types: 0 [533, 28]
# atom numbers: 2055 8
# last atom coords: [11  5  4]
# # end events: 0 1 8
# ee 0 417
# # event types: 0 [536, 32]
# atom numbers: 2056 9
# last atom coords: [15 23  4]
# # end events: 0 3 9
# ee 0 476
# # event types: 0 [538, 36]
# atom numbers: 2057 9
# last atom coords: [26 14  4]
# # end events: 0 1 8
# ee 0 503
# # event types: 0 [541, 40]
# atom numbers: 2058 10
# last atom coords: [30  8  4]
# # end events: 0 3 9
# ee 0 266
# # event types: 0 [543, 44]
# atom numbers: 2059 10
# last atom coords: [25 19  4]
# # end events: 0 1 8
# ee 0 234
# # event types: 0 [546, 48]
# atom numbers: 2060 11
# last atom coords: [16 28  4]
# # end events: 0 3 9
# ee 0 90
# # event types: 0 [548, 52]
# atom numbers: 2061 11
# last atom coords: [14 22  4]
# # end events: 0 1 8
# ee 0 23
# # event types: 0 [551, 56]
# atom numbers: 2062 12
# last atom coords: [ 5 21  4]
# # end events: 0 1 8
# ee 1 18
# # event types: 1 [554, 60]
# atom numbers: 2063 13
# last atom coords: [ 1 15  4]
# diff (16, 12, 4) (15, 13, 4) 2054 [16 12  4]
# # end events: 1 3 15
# ee 0 238
# # event types: 0 [560, 66]
# atom numbers: 2063 13
# last atom coords: [ 1 15  4]
# # end events: 0 5 8
# ee 1 35
# # event types: 1 [563, 66]
# atom numbers: 2064 14
# last atom coords: [15  5  4]
# diff (25, 19, 4) (26, 18, 4) 2059 [25 19  4]
# # end events: 1 9 18
# ee 0 22
# # event types: 0 [566, 72]
# atom numbers: 2064 14
# last atom coords: [15  5  4]
# # end events: 0 4 8
# ee 0 411
# # event types: 0 [569, 73]
# atom numbers: 2065 15
# last atom coords: [ 1 13  4]
# # end events: 0 4 9
# ee 0 373
# # event types: 0 [571, 76]
# atom numbers: 2066 15
# last atom coords: [26 18  4]
# # end events: 0 1 8
# ee 0 346
# # event types: 0 [574, 80]
# atom numbers: 2067 16
# last atom coords: [24  0  4]
# # end events: 0 1 8
# ee 0 123
# # event types: 0 [577, 84]
# atom numbers: 2068 17
# last atom coords: [22 10  4]
# # end events: 0 1 8
# ee 1 83
# # event types: 1 [580, 88]
# atom numbers: 2069 18
# last atom coords: [ 7 29  4]
# diff (22, 10, 4) (21, 9, 4) 2068 [22 10  4]
# # end events: 1 3 15
# ee 0 133
# # event types: 0 [586, 94]
# atom numbers: 2069 18
# last atom coords: [ 7 29  4]
# # end events: 0 5 8
# ee 0 569
# # event types: 0 [589, 94]
# atom numbers: 2070 19
# last atom coords: [ 8 18  4]
# # end events: 0 3 9
# ee 0 394
# # event types: 0 [591, 98]
# atom numbers: 2071 19
# last atom coords: [23 31  4]
# # end events: 0 1 8
# ee 0 240
# # event types: 0 [594, 102]
# atom numbers: 2072 20
# last atom coords: [25 25  4]
# # end events: 0 1 8
# ee 1 91
# # event types: 1 [597, 106]
# atom numbers: 2073 21
# last atom coords: [15 19  4]
# diff (8, 18, 4) (7, 17, 4) 2070 [ 8 18  4]
# # end events: 1 3 15
# ee 0 107
# # event types: 0 [603, 112]
# atom numbers: 2073 21
# last atom coords: [15 19  4]
# # end events: 0 7 9
# ee 0 141
# # event types: 0 [605, 112]
# atom numbers: 2074 21
# last atom coords: [ 6 28  4]
# # end events: 0 1 8
# ee 0 377
# # event types: 0 [608, 116]
# atom numbers: 2075 22
# last atom coords: [9 9 4]
# # end events: 0 1 8
# ee 0 303
# # event types: 0 [611, 120]
# atom numbers: 2076 23
# last atom coords: [24 28  4]
# # end events: 0 1 8
# ee 0 166
# # event types: 0 [614, 124]
# atom numbers: 2077 24
# last atom coords: [20  0  4]
# # end events: 0 1 8
# ee 0 400
# # event types: 0 [617, 128]
# atom numbers: 2078 25
# last atom coords: [10 28  4]
# # end events: 0 3 9
# ee 0 358
# # event types: 0 [619, 132]
# atom numbers: 2079 25
# last atom coords: [26 24  4]
# # end events: 0 1 8
# ee 0 440
# # event types: 0 [622, 136]
# atom numbers: 2080 26
# last atom coords: [23 23  4]
# # end events: 0 1 8
# ee 0 103
# # event types: 0 [625, 140]
# atom numbers: 2081 27
# last atom coords: [29 17  4]
# # end events: 0 3 9
# ee 0 478
# # event types: 0 [627, 144]
# atom numbers: 2082 27
# last atom coords: [ 6 20  4]
# # end events: 0 4 9
# ee 0 210
# # event types: 0 [629, 147]
# atom numbers: 2083 27
# last atom coords: [23 19  4]
# # end events: 0 1 8
# ee 0 218
# # event types: 0 [632, 151]
# atom numbers: 2084 28
# last atom coords: [13 27  4]
# # end events: 0 4 9
# ee 1 114
# # event types: 1 [634, 154]
# atom numbers: 2085 28
# last atom coords: [14 12  4]
# diff (10, 28, 4) (11, 29, 4) 2078 [10 28  4]
# # end events: 1 3 15
# ee 0 193
# # event types: 0 [640, 160]
# atom numbers: 2085 28
# last atom coords: [14 12  4]
# # end events: 0 7 9
# ee 0 452
# # event types: 0 [642, 160]
# atom numbers: 2086 28
# last atom coords: [12 26  4]
# # end events: 0 1 8
# ee 0 207
# # event types: 0 [645, 164]
# atom numbers: 2087 29
# last atom coords: [30 24  4]
# # end events: 0 3 9
# ee 1 46
# # event types: 1 [648, 167]
# atom numbers: 2088 29
# last atom coords: [13 25  4]
# diff (1, 15, 4) (0, 16, 4) 2063 [ 1 15  4]
# # end events: 1 3 15
# ee 0 86
# # event types: 0 [654, 173]
# atom numbers: 2088 29
# last atom coords: [13 25  4]
# # end events: 0 7 9
# ee 0 308
# # event types: 0 [657, 172]
# atom numbers: 2089 29
# last atom coords: [ 5 19  4]
# # end events: 0 1 8
# ee 0 398
# # event types: 0 [660, 176]
# atom numbers: 2090 30
# last atom coords: [20 30  4]
# # end events: 0 1 8
# ee 0 546
# # event types: 0 [663, 180]
# atom numbers: 2091 31
# last atom coords: [27 11  4]
# # end events: 0 1 8
# ee 1 151
# # event types: 1 [666, 184]
# atom numbers: 2092 32
# last atom coords: [23 11  4]
# diff (13, 27, 4) (14, 28, 4) 2084 [13 27  4]
# # end events: 1 6 17
# ee 0 632
# # event types: 0 [671, 190]
# atom numbers: 2092 33
# last atom coords: [23 11  4]
# # end events: 0 7 8
# ee 0 88
# # event types: 0 [673, 189]
# atom numbers: 2093 33
# last atom coords: [11 27  4]
# # end events: 0 3 8
# ee 0 445
# # event types: 0 [675, 192]
# atom numbers: 2094 33
# last atom coords: [ 5 27  4]
# # end events: 0 1 8
# ee 1 168
# # event types: 1 [678, 196]
# atom numbers: 2095 34
# last atom coords: [30 26  4]
# diff (27, 11, 4) (28, 12, 4) 2091 [27 11  4]
# # end events: 1 3 15
# ee 0 201
# # event types: 0 [684, 202]
# atom numbers: 2095 34
# last atom coords: [30 26  4]
# # end events: 0 5 8
# ee 0 582
# # event types: 0 [687, 202]
# atom numbers: 2096 35
# last atom coords: [13 19  4]
# # end events: 0 3 9
# ee 0 109
# # event types: 0 [689, 206]
# atom numbers: 2097 35
# last atom coords: [ 8 10  4]
# # end events: 0 3 8
# ee 0 571
# # event types: 0 [691, 209]
# atom numbers: 2098 35
# last atom coords: [ 7 11  4]
# # end events: 0 1 8
# ee 0 664
# # event types: 0 [694, 213]
# atom numbers: 2099 36
# last atom coords: [ 9 19  4]
# # end events: 0 6 10
# ee 0 388
# # event types: 0 [696, 215]
# atom numbers: 2100 36
# last atom coords: [10 28  4]
# # end events: 0 1 8
# ee 0 99
# # event types: 0 [699, 219]
# atom numbers: 2101 37
# last atom coords: [26 30  4]
# # end events: 0 6 10
# ee 1 114
# # event types: 1 [701, 221]
# atom numbers: 2102 37
# last atom coords: [ 6 18  4]
# diff (25, 25, 4) (24, 24, 4) 2072 [25 25  4]
# # end events: 1 9 18
# ee 0 450
# # event types: 0 [704, 227]
# atom numbers: 2102 37
# last atom coords: [ 6 18  4]
# # end events: 0 4 8
# ee 0 610
# # event types: 0 [707, 228]
# atom numbers: 2103 38
# last atom coords: [31 19  4]
# # end events: 0 3 9
# ee 0 239
# # event types: 0 [710, 231]
# atom numbers: 2104 38
# last atom coords: [15 11  4]
# # end events: 0 1 8
# ee 0 42
# # event types: 0 [713, 235]
# atom numbers: 2105 39
# last atom coords: [16 26  4]
# # end events: 0 1 8
# ee 1 121
# # event types: 1 [716, 239]
# atom numbers: 2106 40
# last atom coords: [ 2 26  4]
# diff (6, 20, 4) (5, 19, 4) 2082 [ 6 20  4]
# # end events: 1 9 17
# ee 1 191
# # event types: 1 [720, 243]
# atom numbers: 2106 40
# last atom coords: [ 2 26  4]
# diff (11, 29, 4) (12, 28, 4) 2078 (11, 29, 4)
# # end events: 1 9 17
# ee 0 399
# # event types: 0 [724, 247]
# atom numbers: 2106 40
# last atom coords: [ 2 26  4]
# # end events: 0 4 8
# ee 1 56
# # event types: 1 [727, 248]
# atom numbers: 2107 41
# last atom coords: [28  8  4]
# diff (1, 13, 4) (2, 12, 4) 2065 [ 1 13  4]
# # end events: 1 3 15
# ee 0 619
# # event types: 0 [733, 254]
# atom numbers: 2107 41
# last atom coords: [28  8  4]
# # end events: 0 10 9
# ee 0 167
# # event types: 0 [735, 251]
# atom numbers: 2108 41
# last atom coords: [14 24  4]
# # end events: 0 1 8
# ee 0 323
# # event types: 0 [738, 255]
# atom numbers: 2109 42
# last atom coords: [11 21  4]
# # end events: 0 4 9
# ee 0 65
# # event types: 0 [741, 257]
# atom numbers: 2110 42
# last atom coords: [22 24  4]
# # end events: 0 1 8
# ee 1 57
# # event types: 1 [744, 261]
# atom numbers: 2111 43
# last atom coords: [ 4 12  4]
# diff (26, 18, 4) (25, 19, 4) 2066 [26 18  4]
# # end events: 1 10 18
# ee 0 179
# # event types: 0 [748, 265]
# atom numbers: 2111 43
# last atom coords: [ 4 12  4]
# # end events: 0 4 8
# ee 0 280
# # event types: 0 [751, 266]
# atom numbers: 2112 44
# last atom coords: [12 16  4]
# # end events: 0 5 11
# ee 1 191
# # event types: 1 [753, 270]
# atom numbers: 2113 44
# last atom coords: [19 31  4]
# diff (31, 19, 4) (30, 18, 4) 2103 [31 19  4]
# # end events: 1 6 15
# ee 1 199
# # event types: 1 [757, 275]
# atom numbers: 2113 43
# last atom coords: [19 31  4]
# diff (2, 26, 4) (3, 27, 4) 2106 [ 2 26  4]
# # end events: 1 6 15
# ee 0 370
# # event types: 0 [763, 278]
# atom numbers: 2113 43
# last atom coords: [19 31  4]
# # end events: 0 5 8
# ee 1 248
# # event types: 1 [766, 278]
# atom numbers: 2114 44
# last atom coords: [26 12  4]
# diff (27, 19, 4) (28, 20, 4) 2052 [27 19  4]
# # end events: 1 4 15
# ee 0 643
# # event types: 0 [772, 283]
# atom numbers: 2114 45
# last atom coords: [26 12  4]
# # end events: 0 7 9
# ee 0 57
# # event types: 0 [774, 283]
# atom numbers: 2115 45
# last atom coords: [31 27  4]
# # end events: 0 1 8
# ee 0 708
# # event types: 0 [777, 287]
# atom numbers: 2116 46
# last atom coords: [ 3 29  4]
# # end events: 0 5 11
# ee 1 262
# # event types: 1 [779, 291]
# atom numbers: 2117 46
# last atom coords: [29  7  4]
# diff (3, 27, 4) (4, 26, 4) 2106 (3, 27, 4)
# # end events: 1 7 14
# ee 1 75
# # event types: 1 [783, 294]
# atom numbers: 2117 45
# last atom coords: [29  7  4]
# diff (7, 17, 4) (6, 18, 4) 2070 (7, 17, 4)
# # end events: 1 12 15
# ee 0 202
# # event types: 0 [787, 293]
# atom numbers: 2117 45
# last atom coords: [29  7  4]
# # end events: 0 5 9
# ee 0 348
# # event types: 0 [789, 295]
# atom numbers: 2118 45
# last atom coords: [14 24  4]
# # end events: 0 1 8
# ee 1 135
# # event types: 1 [792, 299]
# atom numbers: 2119 46
# last atom coords: [25  5  4]
# diff (12, 26, 4) (11, 25, 4) 2086 [12 26  4]
# # end events: 1 6 18
# ee 0 547
# # event types: 0 [796, 307]
# atom numbers: 2119 47
# last atom coords: [25  5  4]
# # end events: 0 5 8
# ee 0 469
# # event types: 0 [799, 307]
# atom numbers: 2120 48
# last atom coords: [ 6 16  4]
# # end events: 0 4 9
# ee 1 43
# # event types: 1 [802, 309]
# atom numbers: 2121 48
# last atom coords: [31  7  4]
# diff (15, 5, 4) (14, 6, 4) 2064 [15  5  4]
# # end events: 1 6 15
# ee 1 262
# # event types: 1 [806, 314]
# atom numbers: 2121 47
# last atom coords: [31  7  4]
# diff (30, 8, 4) (29, 9, 4) 2058 [30  8  4]
# # end events: 1 13 20
# ee 1 294
# # event types: 1 [809, 318]
# atom numbers: 2121 47
# last atom coords: [31  7  4]
# diff (6, 16, 4) (5, 15, 4) 2120 [ 6 16  4]
# # end events: 1 6 15
# ee 0 238
# # event types: 0 [815, 321]
# atom numbers: 2121 47
# last atom coords: [31  7  4]
# # end events: 0 9 11
# ee 0 617
# # event types: 0 [817, 321]
# atom numbers: 2122 47
# last atom coords: [17 27  4]
# # end events: 0 3 9
# ee 1 310
# # event types: 1 [819, 325]
# atom numbers: 2123 47
# last atom coords: [22 12  4]
# diff (5, 15, 4) (4, 14, 4) 2120 (5, 15, 4)
# # end events: 1 4 15
# ee 1 109
# # event types: 1 [825, 330]
# atom numbers: 2123 47
# last atom coords: [22 12  4]
# diff (13, 25, 4) (14, 26, 4) 2088 [13 25  4]
# # end events: 1 9 17
# ee 0 726
# # event types: 0 [829, 334]
# atom numbers: 2123 48
# last atom coords: [22 12  4]
# # end events: 0 12 12
# ee 0 720
# # event types: 0 [831, 332]
# atom numbers: 2124 48
# last atom coords: [20 31  5]
# # end events: 0 3 9
# ee 0 725
# # event types: 0 [833, 336]
# atom numbers: 2125 48
# last atom coords: [13 17  4]
# # end events: 0 4 8
# ee 0 316
# # event types: 0 [835, 338]
# atom numbers: 2126 48
# last atom coords: [31 19  4]
# # end events: 0 1 8
# ee 0 268
# # event types: 0 [838, 342]
# atom numbers: 2127 49
# last atom coords: [23  9  4]
# # end events: 0 4 9
# ee 0 768
# # event types: 0 [841, 344]
# atom numbers: 2128 49
# last atom coords: [19 29  4]
# # end events: 0 5 9
# ee 0 711
# # event types: 0 [843, 346]
# atom numbers: 2129 49
# last atom coords: [13 23  4]
# # end events: 0 10 13
# ee 0 493
# # event types: 0 [845, 347]
# atom numbers: 2130 49
# last atom coords: [ 3 13  4]
# # end events: 0 1 8
# ee 1 140
# # event types: 1 [848, 351]
# atom numbers: 2131 50
# last atom coords: [25 17  4]
# diff (7, 11, 4) (6, 12, 4) 2098 [ 7 11  4]
# # end events: 1 5 17
# ee 0 361
# # event types: 0 [853, 358]
# atom numbers: 2131 51
# last atom coords: [25 17  4]
# # end events: 0 5 8
# ee 1 64
# # event types: 1 [856, 358]
# atom numbers: 2132 52
# last atom coords: [27  1  4]
# diff (7, 17, 4) (6, 18, 4) 0 [27  1  4]
# # end events: 1 7 12
# ee 0 778
# # event types: 0 [863, 356]
# atom numbers: 2132 51
# last atom coords: (6, 18, 4)
# # end events: 0 4 9
# ee 1 171
# # event types: 1 [865, 359]
# atom numbers: 2133 51
# last atom coords: [0 6 4]
# diff (2, 26, 4) (3, 25, 4) 0 [0 6 4]
# # end events: 1 5 11
# ee 1 63
# # event types: 1 [871, 359]
# atom numbers: 2133 51
# last atom coords: (3, 25, 4)
# diff (7, 17, 4) (8, 18, 4) 0 (3, 25, 4)
# # end events: 1 5 12
# ee 1 107
# # event types: 1 [876, 361]
# atom numbers: 2133 51
# last atom coords: (8, 18, 4)
# diff (5, 19, 4) (6, 18, 4) 2082 (5, 19, 4)
# # end events: 1 5 15
# ee 0 198
# # event types: 0 [881, 366]
# atom numbers: 2133 52
# last atom coords: (8, 18, 4)
# # end events: 0 5 8
# ee 0 147
# # event types: 0 [884, 366]
# atom numbers: 2134 53
# last atom coords: [14 30  4]
# # end events: 0 1 8
# ee 0 111
# # event types: 0 [887, 370]
# atom numbers: 2135 54
# last atom coords: [10 30  4]
# # end events: 0 1 8
# ee 0 878
# # event types: 0 [890, 374]
# atom numbers: 2136 55
# last atom coords: [ 8 14  4]
# # end events: 0 3 9
# ee 0 427
# # event types: 0 [892, 378]
# atom numbers: 2137 55
# last atom coords: [15 31  4]
# # end events: 0 6 10
# ee 1 356
# # event types: 1 [893, 381]
# atom numbers: 2138 55
# last atom coords: [29 13  4]
# diff (6, 18, 4) (5, 17, 4) 2082 (6, 18, 4)
# # end events: 1 8 15
# ee 1 305
# # event types: 1 [896, 385]
# atom numbers: 2138 55
# last atom coords: [29 13  4]
# diff (20, 30, 4) (21, 29, 4) 2090 [20 30  4]
# # end events: 1 12 23
# ee 1 11
# # event types: 1 [901, 391]
# atom numbers: 2138 56
# last atom coords: [29 13  4]
# diff (11, 5, 4) (10, 4, 4) 2055 [11  5  4]
# # end events: 1 7 15
# ee 0 411
# # event types: 0 [907, 393]
# atom numbers: 2138 56
# last atom coords: [29 13  4]
# # end events: 0 8 9
# ee 0 83
# # event types: 0 [910, 391]
# atom numbers: 2139 56
# last atom coords: [31 13  4]
# # end events: 0 1 8
# ee 1 198
# # event types: 1 [913, 395]
# atom numbers: 2140 57
# last atom coords: [6 4 4]
# diff (27, 19, 4) (28, 20, 4) 0 [6 4 4]
# # end events: 1 5 9
# ee 0 160
# # event types: 0 [921, 391]
# atom numbers: 2140 57
# last atom coords: (28, 20, 4)
# # end events: 0 1 8
# ee 0 731
# # event types: 0 [924, 395]
# atom numbers: 2141 58
# last atom coords: [12  4  4]
# # end events: 0 3 9
# ee 0 825
# # event types: 0 [926, 399]
# atom numbers: 2142 58
# last atom coords: [ 2 30  4]
# # end events: 0 6 10
# ee 1 97
# # event types: 1 [928, 401]
# atom numbers: 2143 58
# last atom coords: [24 16  4]
# diff (0, 16, 4) (31, 17, 4) 2063 (0, 16, 4)
# # end events: 1 7 15
# ee 0 331
# # event types: 0 [934, 403]
# atom numbers: 2143 57
# last atom coords: [24 16  4]
# # end events: 0 4 8
# ee 0 351
# # event types: 0 [937, 404]
# atom numbers: 2144 58
# last atom coords: [25  9  4]
# # end events: 0 1 8
# ee 1 131
# # event types: 1 [940, 408]
# atom numbers: 2145 59
# last atom coords: [27  5  4]
# diff (8, 10, 4) (9, 11, 4) 2097 [ 8 10  4]
# # end events: 1 6 18
# ee 1 266
# # event types: 1 [945, 415]
# atom numbers: 2145 60
# last atom coords: [27  5  4]
# diff (14, 24, 4) (13, 23, 4) 2118 [14 24  4]
# # end events: 1 13 17
# ee 1 231
# # event types: 1 [949, 415]
# atom numbers: 2145 60
# last atom coords: [27  5  4]
# diff (13, 25, 4) (12, 24, 4) 0 [27  5  4]
# # end events: 1 12 17
# ee 0 725
# # event types: 0 [952, 417]
# atom numbers: 2145 59
# last atom coords: (12, 24, 4)
# # end events: 0 4 9
# ee 1 40
# # event types: 1 [955, 419]
# atom numbers: 2146 59
# last atom coords: [ 2 28  4]
# diff (27, 19, 4) (26, 20, 4) 0 [ 2 28  4]
# # end events: 1 6 11
# ee 0 599
# # event types: 0 [959, 420]
# atom numbers: 2146 59
# last atom coords: (26, 20, 4)
# # end events: 0 3 8
# ee 0 56
# # event types: 0 [961, 423]
# atom numbers: 2147 59
# last atom coords: [ 4 26  4]
# # end events: 0 5 10
# ee 0 705
# # event types: 0 [964, 425]
# atom numbers: 2148 59
# last atom coords: [ 3 27  4]
# # end events: 0 8 12
# ee 0 860
# # event types: 0 [967, 426]
# atom numbers: 2149 59
# last atom coords: [27 13  4]
# # end events: 0 3 9
# ee 0 557
# # event types: 0 [970, 429]
# atom numbers: 2150 59
# last atom coords: [16 30  4]
# # end events: 0 3 9
# ee 1 198
# # event types: 1 [973, 432]
# atom numbers: 2151 59
# last atom coords: [10 28  4]
# diff (31, 27, 4) (0, 26, 4) 2115 [31 27  4]
# # end events: 1 6 18
# ee 1 201
# # event types: 1 [978, 439]
# atom numbers: 2151 60
# last atom coords: [10 28  4]
# diff (3, 29, 4) (4, 30, 4) 2116 [ 3 29  4]
# # end events: 1 11 20
# ee 1 409
# # event types: 1 [982, 444]
# atom numbers: 2151 61
# last atom coords: [10 28  4]
# diff (26, 14, 4) (27, 15, 4) 2057 [26 14  4]
# # end events: 1 10 18
# ee 0 110
# # event types: 0 [986, 448]
# atom numbers: 2151 62
# last atom coords: [10 28  4]
# # end events: 0 5 8
# ee 0 245
# # event types: 0 [989, 448]
# atom numbers: 2152 63
# last atom coords: [ 8 26  4]
# # end events: 0 1 8
# ee 0 390
# # event types: 0 [992, 452]
# atom numbers: 2153 64
# last atom coords: [19 17  4]
# # end events: 0 1 8
# ee 0 990
# # event types: 0 [995, 456]
# atom numbers: 2154 65
# last atom coords: [30 22  4]
# # end events: 0 3 9
# ee 0 450
# # event types: 0 [997, 460]
# atom numbers: 2155 65
# last atom coords: [18 16  4]
# # end events: 0 4 8
# ee 1 297
# # event types: 1 [999, 462]
# atom numbers: 2156 65
# last atom coords: [ 0 16  4]
# diff (10, 30, 4) (11, 29, 4) 2135 [10 30  4]
# # end events: 1 9 14
# ee 0 396
# # event types: 0 [1003, 463]
# atom numbers: 2156 64
# last atom coords: [ 0 16  4]
# # end events: 0 3 8
# ee 0 341
# # event types: 0 [1006, 465]
# atom numbers: 2157 65
# last atom coords: [31  9  4]
# # end events: 0 1 8
# ee 1 126
# # event types: 1 [1009, 469]
# atom numbers: 2158 66
# last atom coords: [26 28  4]
# diff (9, 19, 4) (8, 18, 4) 2099 [ 9 19  4]
# # end events: 1 5 15
# ee 0 586
# # event types: 0 [1014, 474]
# atom numbers: 2158 67
# last atom coords: [26 28  4]
# # end events: 0 7 9
# ee 1 410
# # event types: 1 [1018, 472]
# atom numbers: 2159 67
# last atom coords: [ 6 26  4]
# diff (30, 26, 4) (29, 27, 4) 2095 [30 26  4]
# # end events: 1 4 15
# ee 1 52
# # event types: 1 [1024, 477]
# atom numbers: 2159 67
# last atom coords: [ 6 26  4]
# diff (6, 28, 4) (5, 29, 4) 2074 [ 6 28  4]
# # end events: 1 15 19
# ee 1 166
# # event types: 1 [1026, 479]
# atom numbers: 2159 67
# last atom coords: [ 6 26  4]
# diff (15, 23, 4) (16, 22, 4) 2056 [15 23  4]
# # end events: 1 9 17
# ee 0 260
# # event types: 0 [1031, 482]
# atom numbers: 2159 68
# last atom coords: [ 6 26  4]
# # end events: 0 5 8
# ee 0 230
# # event types: 0 [1034, 482]
# atom numbers: 2160 69
# last atom coords: [20 24  4]
# # end events: 0 1 8
# ee 1 469
# # event types: 1 [1037, 486]
# atom numbers: 2161 70
# last atom coords: [18 20  4]
# diff (7, 29, 4) (6, 30, 4) 2069 [ 7 29  4]
# # end events: 1 7 15
# ee 0 131
# # event types: 0 [1042, 489]
# atom numbers: 2161 70
# last atom coords: [18 20  4]
# # end events: 0 4 8
# ee 0 157
# # event types: 0 [1045, 490]
# atom numbers: 2162 71
# last atom coords: [10 14  4]
# # end events: 0 6 10
# ee 1 372
# # event types: 1 [1047, 492]
# atom numbers: 2163 71
# last atom coords: [12 22  4]
# diff (5, 27, 4) (6, 26, 4) 2094 [ 5 27  4]
# # end events: 1 7 17
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-7c6cd8add6f4> in <module>()
# ----> 1 sim.run()
#
# ~/work/kmcsim/kmcsim/sim/runsim.py in run(self, random_seed)
#     112             t += self.kmc.advance_time()
#     113
# --> 114             self.kmc.step()
#     115
#     116             it += 1
#
# ~/work/kmcsim/kmcsim/sim/model.py in step(self)
#     443
#     444         # perform a step prescribed by the event and return lists of affected events
# --> 445         n_events = self.move(event_type, event_number)
#     446
#     447         # update binary search tree
#
# ~/work/kmcsim/kmcsim/sim/model.py in move(self, event_type, event_number)
#     406
#     407         for i in range(len(self.event_list)):
# --> 408             assert len(self.event_list[i]) == n_events[i], f'Number of events of type {i} does not match: {len(self.event_list[i])} vs. {n_events[i]}'
#     409
#     410         # update atom count
#
# AssertionError: Number of events of type 1 does not match: 498 vs. 497

# %%
sim.output()
